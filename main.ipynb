# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import re
from geopy.geocoders import Nominatim
from geopy.point import Point
from cProfile import label

# %%
from src import cleaning_michelin
from src import cleaning_web_scraping
from src import merging_function
#from src import visualization
df_michelin = cleaning_michelin.clean_csv()
df_temp_continents = cleaning_web_scraping.cleaning_continent_df()
df_Michelin_temp = merging_function.merge_michelin_and_temp(df_michelin, df_temp_continents)
df_michelin.to_csv("./Data/Cleaned_data/michelin_cleaned.csv", index=False)
df_temp_continents.to_csv("./Data/Cleaned_data/df_temp_cleaned.csv", index=False)
df_Michelin_temp.to_csv("./Data/df_Michelin_temp.csv", index=False)

#df = visualization.visuals()
# Columns to match

# %%
df_Michelin_temp
# Out:
#                              Name Price                       Cuisine  \
# 7            Restavracija Strelec   $$$                Modern Cuisine
# 9               Gostilna na Gradu    $$           Traditional Cuisine
# 15                          TaBar    $$  Modern Cuisine, Contemporary
# 18                      Le Palais  $$$$                     Cantonese
# 19                       Taïrroir  $$$$        Taiwanese contemporary
# ...                           ...   ...                           ...
# 25722  Dejvická 34 by Tomáš Černý     $                       Italian
# 25723                  The Eatery     $                         Czech
# 25724                    Na Kopci     $           Traditional Cuisine
# 25725                        Eska     $           Traditional Cuisine
# 25726      Iva New Balkan Cuisine     $                Modern Cuisine
#
#                   Award                              FacilitiesAndServices  \
# 7       1 Star MICHELIN  Credit card / Debit card accepted,Garden or pa...
# 9          Bib Gourmand  Car park,Credit card / Debit card accepted,Din...
# 15         Bib Gourmand  Air conditioning,Credit card / Debit card acce...
# 18     3 Stars MICHELIN  Air conditioning,American Express credit card,...
# 19     3 Stars MICHELIN  Air conditioning,American Express credit card,...
# ...                 ...                                                ...
# 25722      Bib Gourmand  Air conditioning,American Express credit card,...
# 25723      Bib Gourmand  Air conditioning,Counter dining,Credit card / ...
# 25724      Bib Gourmand  Air conditioning,American Express credit card,...
# 25725      Bib Gourmand  Air conditioning,American Express credit card,...
# 25726      Bib Gourmand  Air conditioning,Credit card / Debit card acce...
#
#                                              Description  \
# 7      The climb up to the castle offers a fine intro...
# 9      This restaurant serving top-quality local cuis...
# 15     This simple, informal and friendly restaurant ...
# 18     After the departure of the Macanese chef, the ...
# 19     A portmanteau of Taiwan and terroir, Taïrroir ...
# ...                                                  ...
# 25722  Chef-owner Tomaš Černy worked in the best Ital...
# 25723  This highly regarded restaurant in the suburbs...
# 25724  Leave the city behind and escape to this buzzy...
# 25725  A café, bakery and restaurant in a converted f...
# 25726  There’s great value to be had at this semi-bas...
#
#                      Combined       City         Country Continent  ...   Apr  \
# 7          46.04829, 14.50869  Ljubljana        Slovenia    Europe  ...  10.8
# 9      46.0478785, 14.5092591  Ljubljana        Slovenia    Europe  ...  10.8
# 15     46.0501886, 14.5061621  Ljubljana        Slovenia    Europe  ...  10.8
# 18       25.049071, 121.51696     Taipei          Taiwan      Asia  ...  21.9
# 19      25.082896, 121.559303     Taipei          Taiwan      Asia  ...  21.9
# ...                       ...        ...             ...       ...  ...   ...
# 25722  50.0987928, 14.3992062     Prague  Czech Republic    Europe  ...   8.4
# 25723  50.1074835, 14.4507679     Prague  Czech Republic    Europe  ...   8.4
# 25724  50.0566218, 14.4022425     Prague  Czech Republic    Europe  ...   8.4
# 25725   50.091347, 14.4547205     Prague  Czech Republic    Europe  ...   8.4
# 25726  44.8197396, 20.4610962   Belgrade          Serbia    Europe  ...  12.9
#
#         May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  Year
# 7      15.8  19.1  21.3  20.6  16.0  11.2   5.6   1.2  10.9
# 9      15.8  19.1  21.3  20.6  16.0  11.2   5.6   1.2  10.9
# 15     15.8  19.1  21.3  20.6  16.0  11.2   5.6   1.2  10.9
# 18     25.2  27.7  29.6  29.2  27.4  24.5  21.5  17.9  23.0
# 19     25.2  27.7  29.6  29.2  27.4  24.5  21.5  17.9  23.0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 25722  13.4  16.1  18.2  17.8  13.5   8.5   3.1   0.3   8.4
# 25723  13.4  16.1  18.2  17.8  13.5   8.5   3.1   0.3   8.4
# 25724  13.4  16.1  18.2  17.8  13.5   8.5   3.1   0.3   8.4
# 25725  13.4  16.1  18.2  17.8  13.5   8.5   3.1   0.3   8.4
# 25726  18.1  21.0  23.0  22.7  18.0  12.9   7.1   2.7  12.5
#
# [2195 rows x 23 columns]
