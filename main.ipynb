# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import re
from geopy.geocoders import Nominatim
from geopy.point import Point
from cProfile import label

# %%
df = pd.read_csv("../Project-II-Data-Pipeline/Data/michelin_my_maps.csv",sep=',' ,encoding= 'utf-8')
df.drop(columns=["Url","WebsiteUrl","PhoneNumber"], inplace=True)
df['Combined'] = df['Latitude'].astype(str) + ', ' + df['Longitude'].astype(str)
#df.drop(columns=["Longitude","Latitude", "Location"], inplace=True)

# %%
df
# Out:
#                   Name                                            Address  \
# 0          Hiša Franko              Staro selo 1, Kobarid, 5222, Slovenia
# 1            Le Palais  17F, Palais de Chine Hotel, 3, Section 1, Chen...
# 2             Taïrroir  6F, 299 Lequn 3rd Road, Zhongshan District, Ta...
# 3            JL Studio  2F, 689, Section 4, Yifeng Road, Nantun Distri...
# 4        Atelier Crenn       3127 Fillmore St., San Francisco, 94123, USA
# ...                ...                                                ...
# 6979  Eder's Eichmühle          Eichmühle 2, Wädenswil, 8820, Switzerland
# 6980    f39 restaurant      Fröhlichstrasse 39, Zurich, 8008, Switzerland
# 6981          Helvetia  Vonwilstrasse 39, Sankt Gallen, 9000, Switzerland
# 6982   Schloss Wartegg  Von Blarer-Weg 1, Rorschacherberg, 9404, Switz...
# 6983             Gigas  2F, 8-7 Dosan-daero 45-gil, Gangnam-gu, Seoul,...
#
#                           Location Price                         Cuisine  \
# 0                Kobarid, Slovenia  €€€€      Creative, Regional Cuisine
# 1                   Taipei, Taiwan  $$$$                       Cantonese
# 2                   Taipei, Taiwan  $$$$          Taiwanese contemporary
# 3                 Taichung, Taiwan  $$$$       Singaporean, Contemporary
# 4               San Francisco, USA  $$$$            Contemporary, French
# ...                            ...   ...                             ...
# 6979        Wädenswil, Switzerland   €€€   Market Cuisine, International
# 6980           Zurich, Switzerland  €€€€                  Modern Cuisine
# 6981     Sankt Gallen, Switzerland   €€€  Contemporary, Regional Cuisine
# 6982  Rorschacherberg, Switzerland    €€                Regional Cuisine
# 6983            Seoul, South Korea   ₩₩₩           Mediterranean Cuisine
#
#        Longitude   Latitude                Award  \
# 0      13.538236  46.247296     3 Stars MICHELIN
# 1     121.516960  25.049071     3 Stars MICHELIN
# 2     121.559303  25.082896     3 Stars MICHELIN
# 3     120.628520  24.150486     3 Stars MICHELIN
# 4    -122.435860  37.798350     3 Stars MICHELIN
# ...          ...        ...                  ...
# 6979    8.681457  47.214296  MICHELIN Green Star
# 6980    8.556231  47.354512  MICHELIN Green Star
# 6981    9.356780  47.418838  MICHELIN Green Star
# 6982    9.529886  47.478512  MICHELIN Green Star
# 6983  127.036380  37.523022  MICHELIN Green Star
#
#                                   FacilitiesAndServices  \
# 0     Air conditioning,Car park,Credit card / Debit ...
# 1     Air conditioning,American Express credit card,...
# 2     Air conditioning,American Express credit card,...
# 3     Air conditioning,American Express credit card,...
# 4     Air conditioning,American Express credit card,...
# ...                                                 ...
# 6979  American Express credit card,Car park,Credit c...
# 6980  American Express credit card,Credit card / Deb...
# 6981  Credit card / Debit card accepted,Mastercard c...
# 6982  American Express credit card,Car park,Credit c...
# 6983  Air conditioning,American Express credit card,...
#
#                                             Description  \
# 0     Ana Roš Stojan’s cuisine is the perfect reflec...
# 1     After the departure of the Macanese chef, the ...
# 2     A portmanteau of Taiwan and terroir, Taïrroir ...
# 3     JL stands for Jimmy Lim, a Singaporean chef wh...
# 4     At the hands of accomplished Chef Dominique Cr...
# ...                                                 ...
# 6979  This former farm house with its fantastic gard...
# 6980  Somewhat hidden away in the Seefeld quarter is...
# 6981  In Svenja and Adrian Nessensohn (both recent g...
# 6982  The elevated location between Lake Constance a...
# 6983  This authentic Mediterranean restaurant is a r...
#
#                      Combined
# 0      46.2472961, 13.5382362
# 1        25.049071, 121.51696
# 2       25.082896, 121.559303
# 3     24.1504863, 120.6285199
# 4        37.79835, -122.43586
# ...                       ...
# 6979    47.2142963, 8.6814569
# 6980    47.3545122, 8.5562311
# 6981      47.4188376, 9.35678
# 6982    47.4785116, 9.5298861
# 6983  37.5230221, 127.0363798
#
# [6984 rows x 11 columns]

# %%
geolocator = Nominatim(user_agent="test")

def reverse_geocoding(lat, lon):
    try:
        location = geolocator.reverse(Point(lat, lon))
        return location.raw['display_name']
    except:
        return None

# %%
df_sample = df.sample()
df_sample
# Out:
#           Name                                            Address  \
# 6536  Shigetsu  68 Sagatenryuji Susukinobabacho, Ukyo-ku, Kyot...
#
#           Location Price Cuisine   Longitude   Latitude         Award  \
# 6536  Kyoto, Japan    ¥¥  Shojin  135.673591  35.015281  Bib Gourmand
#
#                                   FacilitiesAndServices  \
# 6536  Air conditioning,American Express credit card,...
#
#                                             Description               Combined
# 6536  Kyoto is the birthplace of many culinary tradi...  35.015281, 135.673591

# %%
df_sample['address'] = np.vectorize(reverse_geocoding)(df['Latitude'], df['Longitude'])

df_sample['address']
